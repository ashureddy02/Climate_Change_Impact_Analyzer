# %%
import pandas as pd
crop_df = pd.read_csv("../data/processed/crop_clean.csv")
temp_df = pd.read_csv("../data/processed/temperature_clean.csv")
rain_df = pd.read_csv("../data/processed/rainfall_clean.csv")

# %%
# Merge rainfall and temperature on Year
climate_df = pd.merge(
    rain_df,
    temp_df,
    on="Year",
    how="inner"
)

# Merge with crop data ONLY on Year
final_df = pd.merge(
    climate_df,
    crop_df,
    on="Year",
    how="inner"
)

print(len(final_df))
final_df.head()
# Out:
# 18684
#                      State_x  Year  Annual_Rainfall  Avg_Temperature  \
# 0  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 1  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 2  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 3  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 4  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
#
#              State_y  Total_Production
# 0     Andhra Pradesh        21093500.0
# 1  Arunachal Pradesh          267148.0
# 2              Assam         5778334.0
# 3              Bihar        19031372.0
# 4                Goa           72538.0

# %%
# we are taking Average rainfall per rainfall-region (State_x)
final_df["Avg_Rainfall_State"] = final_df.groupby("State_x")[
    "Annual_Rainfall"
].transform("mean")

# Difference from average rainfall
final_df["Rainfall_Deviation"] = (
    final_df["Annual_Rainfall"] - final_df["Avg_Rainfall_State"]
)

final_df.head()
# Out:
#                      State_x  Year  Annual_Rainfall  Avg_Temperature  \
# 0  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 1  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 2  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 3  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 4  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
#
#              State_y  Total_Production Temp_Level  Avg_Rainfall_State  \
# 0     Andhra Pradesh        21093500.0       High          2890.44605
# 1  Arunachal Pradesh          267148.0       High          2890.44605
# 2              Assam         5778334.0       High          2890.44605
# 3              Bihar        19031372.0       High          2890.44605
# 4                Goa           72538.0       High          2890.44605
#
#    Rainfall_Deviation
# 0          -135.34605
# 1          -135.34605
# 2          -135.34605
# 3          -135.34605
# 4          -135.34605

# %%
# Simple temperature category
def temp_category(temp):
    if temp < 24:
        return "Low"
    elif temp < 28:
        return "Medium"
    else:
        return "High"

final_df["Temp_Level"] = final_df["Avg_Temperature"].apply(temp_category)

final_df.tail()
# Out:
#            State_x  Year  Annual_Rainfall  Avg_Temperature        State_y  \
# 18679  LAKSHADWEEP  2014           1395.0        29.723333  Uttar Pradesh
# 18680  LAKSHADWEEP  2014           1395.0        29.723333    Uttarakhand
# 18681  LAKSHADWEEP  2014           1395.0        29.723333    West Bengal
# 18682  LAKSHADWEEP  2015           1642.9        29.895000         Odisha
# 18683  LAKSHADWEEP  2015           1642.9        29.895000         Sikkim
#
#        Total_Production Temp_Level  Avg_Rainfall_State  Rainfall_Deviation
# 18679       199418844.0       High         1602.065125         -207.065125
# 18680        11873861.0       High         1602.065125         -207.065125
# 18681        43584403.0       High         1602.065125         -207.065125
# 18682         6831648.7       High         1602.065125           40.834875
# 18683          103416.0       High         1602.065125           40.834875

# %%
import numpy as np

# we apply log transformations to reduce the skewness of the production data
final_df["Log_Production"] = np.log1p(final_df["Total_Production"])

final_df.head()
# Out:
#                      State_x  Year  Annual_Rainfall  Avg_Temperature  \
# 0  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 1  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 2  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 3  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
# 4  ANDAMAN & NICOBAR ISLANDS  1997           2755.1        29.179167
#
#              State_y  Total_Production Temp_Level  Avg_Rainfall_State  \
# 0     Andhra Pradesh        21093500.0       High          2890.44605
# 1  Arunachal Pradesh          267148.0       High          2890.44605
# 2              Assam         5778334.0       High          2890.44605
# 3              Bihar        19031372.0       High          2890.44605
# 4                Goa           72538.0       High          2890.44605
#
#    Rainfall_Deviation  Log_Production
# 0          -135.34605       16.864476
# 1          -135.34605       12.495562
# 2          -135.34605       15.569626
# 3          -135.34605       16.761599
# 4          -135.34605       11.191880

# %%
print(final_df.columns)

print( len(final_df))
print( final_df.shape[1])
# Out:
# Index(['State_x', 'Year', 'Annual_Rainfall', 'Avg_Temperature', 'State_y',
#        'Total_Production', 'Temp_Level', 'Avg_Rainfall_State',
#        'Rainfall_Deviation', 'Log_Production'],
#       dtype='object')
# 18684
# 10

# %%
from pathlib import Path

processed_dir = Path("../data/processed")
processed_dir.mkdir(parents=True, exist_ok=True)

final_df.to_csv(processed_dir / "engineered_features.csv", index=False)
